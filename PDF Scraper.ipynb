# %%
import PyPDF2

# %%
reader = PyPDF2.PdfFileReader('C:/Users/Nigel/Downloads/article1.pdf')
 
# printing number of pages in pdf file
reader.getNumPages()
 
# getting a specific page from the pdf file
page = reader.pages[0]
# extracting text from page
#text = reader.

# %%
reader = PyPDF2.PdfFileReader('C:/Users/Nigel/Downloads/article1.pdf')

# %%
def textProcessor(reader):
    processedText=""
    for pageNo in range(reader.getNumPages()):
        page = reader.pages[pageNo]
        info = page.extractText()
        info=info.rstrip("\n")
        char=0;
        while char < len(info):
            #clean up the text to be used for summary
            if(char!=len(info)-1 and info[char:char+2]=="\n"):
                processedText+=(" ")
            elif(info[char:char+2]=="  "):
                processedText+=("")
            elif(info[char]=="˚" and info[char+1]!=" "):
                processedText+=("Th")
            elif(info[char]=="˝"):
                processedText+="f"
            elif(info[char]=="˜" and info[char-1].isalpha()):
                processedText+="ff"
            elif(info[char]=="-"):
                char+=2
            elif(info[char]==" " and info[char-1].isnumeric()):
                processedText+=("")
            else:
                processedText+=info[char]
            char+=1
    #return furnished and cleaned text
    return processedText

# %%
import openai

# %%
openai.api_key = "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"
# Set the model and prompt
model_engine = "text-davinci-003"

def chatgpt_header(text):
    prompt = "Provide a header for the text: " + text

    # Maximum number of tokens for response
    max_tokens = 256

    # Generate a response
    completion = openai.Completion.create(
        engine=model_engine,
        prompt=prompt,
        max_tokens=max_tokens,
        temperature=0.5,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )

    # Return the response
    return completion.choices[0].text.strip()
def chatgpt_summarise(text):
    prompt = "Summarise this in a paragraph: " + text

    # Maximum number of tokens for response
    max_tokens = 256

    # Generate a response
    completion = openai.Completion.create(
        engine=model_engine,
        prompt=prompt,
        max_tokens=max_tokens,
        temperature=0.5,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )

    # Return the response
    return completion.choices[0].text.strip()

# %%
import pandas as pd

# %%
import io
processedText=textProcessor(reader)
data = []
df = pd.DataFrame(data, columns=['Header','Paragraph'])
itrs=int(len(processedText)/4097)+1
list1=[]
header1=[]
for i in range(0,len(processedText),4097):
    header1uncut=chatgpt_header(processedText[i:i+4097])
    idx=header1uncut.find("Header:")
    header1.append(header1uncut[idx+7:])
    list1.append(chatgpt_summarise(processedText[i:i+4097]))
df['Paragraph']=list1
df['Header']=header1

# %%
df
# Out:
#                                               Header  \
# 0  \nThe Effectiveness of Structured Diabetes Sel...
# 1   envelopes.\n\nHEADER: Investigating the Effec...
# 2   Randomized Controlled Trial of Structured DSM...
# 3  y\n22(22%)17(17%)39(19%) Secondary\n58(57%)63(...
# 4   Effect of Structured DSME on Glycaemic Contro...
# 5   Investigating the Impact of Structured Diabet...
# 6  ructured  diabetes  selfmanagement  education ...
# 7   Evaluating the Impact of Structured DSME on G...
# 8  lett M, Khunti K, \nCarey ME, Davies MJ. Cost ...
# 9  iveness of Structured Group Education Programm...
#
#                                            Paragraph
# 0  diabetes selfmanagement education (DSME) is as...
# 1  eblinded envelopes.\nIn summary, this study fo...
# 2  participants were recruited per group.\n\nThis...
# 3  Primary\n29(28%)27(26%)56(27%) Secondary\n50(4...
# 4  for 3\nnths\n\nIn this study, a structured DSM...
# 5  ht a recently published systematic review of s...
# 6  of DSME in resource constrained settings. In t...
# 7  arch Centre, Leicester, UK. \n7Department of\n...
# 8  R, Davies MJ. Cost \neffectiveness of the diab...
# 9  This article reviews 29 studies on the effecti...

# %%
for i in range(5):
    print(df['Header'][i])
    print("____________________________________________________Header______________________________")
    print(df['Paragraph'][i])
    print("____________________________________________________Paragraph______________________________")
# Out:
# The Effectiveness of Structured Diabetes Self-Management Education in Low-Resource Settings: A Multicentre Randomised Trial
# ____________________________________________________Header______________________________
# diabetes selfmanagement education (DSME) is associated with improved outcomes.
# Ł The evidence from low
# source settings is limited and inconclusive.
# What doesffthis study add?
# Ł In low
# source settings, structured diabetes self
# nagement education is not associated with glycaemic control.
# Ł Clinicians expectations from diabetes self
# nagement education must be guarded.
# This study investigated the effect of structured diabetes self-management education (DSME) on glycaemic control in adults with type 2 diabetes in low-resource settings. 206 participants from two hospitals in urban Ghana were randomly assigned to either usual care or usual care plus DSME. Results showed that there was a reduction in HbA1c in both groups, but the intervention effect was not statistically significant. The study suggests that DSME may not be associated with glycaemic control in low-resource settings and clinicians should be aware of this when considering DSME as a treatment option.
# ____________________________________________________Paragraph______________________________
#  envelopes.
#
# HEADER: Investigating the Effect of Structured Diabetes Self-Management Education on Glycemic Control in Low-Resource Settings in Accra, Ghana
# ____________________________________________________Header______________________________
# eblinded envelopes.
# In summary, this study found that diabetes self-management education is associated with improved outcomes, as evidenced by a decrease in HbA1c levels in both the intervention and control arms. However, the effect size of the structured DSME intervention on glycaemic control may be limited in low-resource settings, suggesting that clinicians should have guarded expectations from diabetes education.
# ____________________________________________________Paragraph______________________________
#  Randomized Controlled Trial of Structured DSME Program in Ghana
# ____________________________________________________Header______________________________
# participants were recruited per group.
#
# This study recruited 206 participants from two hospitals in Ghana, which were randomly assigned to either a structured DSME program or the usual care. The primary outcome was change in HbA1c after 3 months follow-up, and secondary outcomes included changes in clinical, psychological, and self-care variables. The intervention was delivered by providers not directly involved in patient care, and data was collected at baseline and 3 months after randomisation. Adverse events were also assessed using a standardised questionnaire.
# ____________________________________________________Paragraph______________________________
# y
# 22(22%)17(17%)39(19%) Secondary
# 58(57%)63(61%)121(59%) Tertiary
# 23(22%)23(22%)46(22%)Unemployment
#  Nss
# 101 N10210320 Unemployed
# 30(30%)27(26%)57(28%) Employed
# 73(71%)76(74%)149(72%)Income
#  Nss
# 101 N10210320 Median
#
# (Q1
# ¶, Q3#)
# 400(250, 700)400(250, 700)400(250, 700)WHOQoL
#  Nss
# 101 N10210320 Median
#
# (Q1
# ¶, Q3#)
# 90(80, 100)90(80, 100)90(80, 100)SDSCA
#  Nss
# 101 N10210320 Diet
# Median
#
# (Q1
# ¶, Q3#)
# 1(1, 2)1(1, 2)1(1, 2) Exercise
# Median
#
# (Q1
# ¶, Q3#)
# 1(1, 2)1(1, 2)
# ____________________________________________________Header______________________________
# Primary
# 29(28%)27(26%)56(27%) Secondary
# 50(49%)51(50%)101(49%) Tertiary
# 23(22%)25(24%)48(23%) Marital Status
#  Nss
# 101 N10210320 Single
# 25(24%)26(25%)51(25%) Married
# 78(76%)77(75%)155(75%) Widowed
# 0(0%)0(0%)0(0%) Divorced
# 0(0%)0(0%)0(0%) Separated
# 0(0%)0(0%)0(0%) Employment Status
#  Nss
# 101 N10210320 Employed
# 25(24%)25(24%)50(24%) Unemployed
# 78(76%)77(75%)155(76%) Income
#  Nss
# 101 N10210320 Low
# 68(66%)68(66%)136(66%) Middle
# 32(31%)32(31%)64(31%) High
# 3(3%)3(3%)6(3%) Literacy
#  Nss
# 101 N10210320 Low
# 63(61%)63(61%)126(61%) High
# 40(39%)40
# ____________________________________________________Paragraph______________________________
#  Effect of Structured DSME on Glycaemic Control in People Living with Diabetes in Resource-Constrained Settings
# ____________________________________________________Header______________________________
# for 3
# nths
#
# In this study, a structured DSME intervention was tested for its effect on HbA1c levels in people living with diabetes in resource-constrained settings. The intervention did not have a significant effect on HbA1c levels at 3 months, although the intervention group showed a greater decrease in HbA1c than the control group. There was insufficient evidence that the intervention had an effect on any of the secondary outcomes except for an improvement in physical health. No significant adverse events were observed.
# ____________________________________________________Paragraph______________________________
