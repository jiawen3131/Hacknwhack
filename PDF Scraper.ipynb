# %%
import PyPDF2

# %%
reader = PyPDF2.PdfFileReader('C:/Users/Nigel/Downloads/article1.pdf')
 
# printing number of pages in pdf file
reader.getNumPages()
 
# getting a specific page from the pdf file
page = reader.pages[0]
# extracting text from page
#text = reader.

# %%
reader = PyPDF2.PdfFileReader('C:/Users/Nigel/Downloads/article1.pdf')

# %%
def textProcessor(reader):
    processedText=""
    for pageNo in range(reader.getNumPages()):
        page = reader.pages[pageNo]
        info = page.extractText()
        info=info.rstrip("\n")
        char=0;
        while char < len(info):
            if(char!=len(info)-1 and info[char:char+2]=="\n"):
                processedText+=(" ")
            elif(info[char:char+2]=="  "):
                processedText+=("")
            elif(info[char]=="˚" and info[char+1]!=" "):
                processedText+=("Th")
            elif(info[char]=="˝"):
                processedText+="f"
            elif(info[char]=="˜" and info[char-1].isalpha()):
                processedText+="ff"
            elif(info[char]=="-"):
                char+=2
            #elif(info[char]=="["):
             #   print("\n[",end="")
              #  char+=2;
            elif(info[char]==" " and info[char-1].isnumeric()):
                processedText+=("")
            else:
                processedText+=info[char]
            char+=1
    return processedText

# %%
import openai

# %%
openai.api_key = "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"
# Set the model and prompt
model_engine = "text-davinci-003"

def chatgpt_header(text):
    prompt = "Provide a header for the text: " + text

    # Set the maximum number of tokens to generate in the response
    max_tokens = 256

    # Generate a response
    completion = openai.Completion.create(
        engine=model_engine,
        prompt=prompt,
        max_tokens=max_tokens,
        temperature=0.5,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )

    # Print the response
    return completion.choices[0].text.strip()
def chatgpt_summarise(text):
    prompt = "Summarise this a paragraph: " + text

    # Set the maximum number of tokens to generate in the response
    max_tokens = 256

    # Generate a response
    completion = openai.Completion.create(
        engine=model_engine,
        prompt=prompt,
        max_tokens=max_tokens,
        temperature=0.5,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )

    # Print the response
    return completion.choices[0].text.strip()

# %%
header=[]
itrs=int(len(processedText)/4097)+1
for i in range(0,len(processedText),4097):
    header.append(chatgpt_header(processedText[i:i+4097]))
    print(chatgpt_summarise(processedText[i:i+4097]))
# Out:
# diabetes selfnagement education is associated with improved
# outcomes.
# Ł The evidence from low
# source settings is limited and inconclusive.
# Main points:
# 1. This study compared structured diabetes self-management education to usual care in adults with type 2 diabetes in low-resource settings.
# 2. 206 participants were randomised and primary outcome data was available for 79 and 80 participants in the intervention and control groups, respectively.
# 3. The intervention effect was not significant, with a reduction in HbA1c of 1 mmol/mol in the intervention group and 0.1% in the control group.
# envelopes.
# Main points:
# • Diabetes self-management education did not have a significant effect on HbA1c at 3 months in low-resource settings.
# • HbA1c decreased in both intervention and control arms, with a greater decrease in the intervention arm.
# • Diabetes self-management education may have a limited effect size on glycaemic control in low-resource settings.
# ...

# %%
len(processedText)
# Out:
# 40644

# %%
import pandas as pd

# %%
import io
data = []
df = pd.DataFrame(data, columns=['Header','Paragraph'])
itrs=int(len(processedText)/4097)+1
list1=[]
header1=[]
for i in range(0,len(processedText),4097):
    header1uncut=chatgpt_header(processedText[i:i+4097])
    idx=header1uncut.find("Header:")
    header1.append(header1uncut[idx+7:])
    list1.append(chatgpt_summarise(processedText[i:i+4097]))
df['Paragraph']=list1
df['Header']=header1

# %%
df
# Out:
#                                                Header  \
# 0   \nAssessing the Effectiveness of Structured Di...
# 1   pes.\n\nHEADER: Investigating the Effect of St...
# 2    Evaluating the Efficacy of a Structured Diabe...
# 3   y\n17(17%)19(18%)36(18%) Secondary\n77(76%)78(...
# 4    Effect of Structured Diabetes Self-Management...
# 5    Examining the Effect of Structured Diabetes S...
# 6   uctured DSME on \nglycaemic control in low and...
# 7    Evaluation of the Impact of Structured DSME o...
# 8   lett M, Heller S, \nKhunthi K, Skinner T, Davi...
# 9   as you give appropriate credit to the original...
# 10   Evaluating the Effectiveness of Diabetes Self...
# 11  \nEffect of Structured Diabetes Self-Managemen...
# 12   time, we decided to recruit \nan additional 1...
# 13   Comparative Analysis of Intervention Effect o...
# 14   Effect of Structured DSME on HbA1c in People ...
# 15   Structured Diabetes Self-Management Education...
# ...

# %%
for i in range(5):
    print(df['Header'][i])
    print("____________________________________________________Header______________________________")
    print(df['Paragraph'][i])
    print("____________________________________________________Paragraph______________________________")
# Out:
# Assessing the Effectiveness of Structured Diabetes Self-Management Education in Low-Resource Settings
# ____________________________________________________Header______________________________
# diabetes selfmanagement education is associated with improved glycaemic outcomes.
# What doesffthis study add?
# Ł In low source settings, structured diabetes self management education may not be associated with improved glycaemic outcomes.
# This article examines the effectiveness of a structured diabetes self-management education program in low-resource settings in adults with type 2 diabetes. It found that while there was a reduction in HbA1c in both the intervention and control groups, the intervention effect was not statistically significant. It concluded that in low-resource settings, diabetes self-management education may not be associated with improved glycaemic outcomes.
# ____________________________________________________Paragraph______________________________
# pes.
#
# ...
